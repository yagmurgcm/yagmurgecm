# %% [markdown]
# <a href="https://colab.research.google.com/github/yagmurgcm/yagmurgecm/blob/main/eda%2Bhypthesist.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this document, I have 6 data set:
# 1. Google Seach Trends for "faiz"
# 2. Google Seach Trends for "dolar"
# 3. Google Seach Trends for "euro"
# 4. Google Seach Trends for "enflasyon"
# 5. TCMB- Monthly Inflation Rates
# 6. TCMB- Monthly Interest Rates

# %% [markdown]
# In this document, each data set will be visualized by using bar charts and line charts. Also, the first five element of each data set will shown to understand data set better.

# %%
import pandas as pd
from google.colab import drive
import os
import matplotlib.pyplot as plt

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # **Google Seach Trends for "faiz"**

# %%
file_path = '/content/drive/My Drive/dsa210/monthly_faiz.csv'
faiz_df = pd.read_csv(file_path, skiprows=1)

faiz_df.columns = ["Month", "faiz_trend"]
faiz_df["Month"] = pd.to_datetime(faiz_df["Month"])

#print first 5 element
print(faiz_df.head())

#Bar chart
plt.figure(figsize=(16, 6))
plt.bar(faiz_df["Month"].dt.strftime('%Y-%m'), faiz_df["faiz_trend"], color='hotpink')
plt.title("Monthly Average Trend: Faiz")
plt.xlabel("Month")
plt.ylabel("Trend Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Line chart
plt.figure(figsize=(16, 6))
plt.plot(faiz_df["Month"], faiz_df["faiz_trend"], marker='o', color='hotpink')
plt.title("Monthly Average Trend: Faiz")
plt.xlabel("Month")
plt.ylabel("Trend Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#        Month  faiz_trend
# 0 2020-04-01       18.00
# 1 2020-05-01       26.20
# 2 2020-06-01       26.50
# 3 2020-07-01       19.75
# 4 2020-08-01       25.40

# %% [markdown]
# # **Google Search Trends for "dolar"**

# %%
# Dolar
file_path = '/content/drive/My Drive/dsa210/monthly_dolar.csv'
dolar_df = pd.read_csv(file_path, skiprows=1)

dolar_df.columns = ["Month", "dolar_trend"]
dolar_df["Month"] = pd.to_datetime(dolar_df["Month"])

#print first 5 element
print(dolar_df.head())

#Bar chart
plt.figure(figsize=(16, 6))
plt.bar(dolar_df["Month"].dt.strftime('%Y-%m'), dolar_df["dolar_trend"], color='skyblue')
plt.title("Monthly Average Trend: Dolar")
plt.xlabel("Month")
plt.ylabel("Trend Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Line chart
plt.figure(figsize=(16, 6))
plt.plot(dolar_df["Month"], dolar_df["dolar_trend"], marker='o', color='skyblue')
plt.title("Monthly Average Trend: Dolar")
plt.xlabel("Month")
plt.ylabel("Trend Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#        Month  dolar_trend
# 0 2020-04-01         6.00
# 1 2020-05-01         6.20
# 2 2020-06-01         4.25
# 3 2020-07-01         4.50
# 4 2020-08-01         8.60

# %% [markdown]
# # **Google Search Trends for "euro"**

# %%
# Euro
file_path = '/content/drive/My Drive/dsa210/monthly_euro.csv'
euro_df = pd.read_csv(file_path, skiprows=1)

euro_df.columns = ["Month", "euro_trend"]
euro_df["Month"] = pd.to_datetime(euro_df["Month"])

#print first 5 element
print(euro_df.head())

#Bar chart
plt.figure(figsize=(16, 6))
plt.bar(euro_df["Month"].dt.strftime('%Y-%m'), euro_df["euro_trend"], color='purple')
plt.title("Monthly Average Trend: Euro")
plt.xlabel("Month")
plt.ylabel("Trend Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Line chart
plt.figure(figsize=(16, 6))
plt.plot(euro_df["Month"], euro_df["euro_trend"], marker='o', color='purple')
plt.title("Monthly Average Trend: Euro")
plt.xlabel("Month")
plt.ylabel("Trend Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#        Month  euro_trend
# 0 2020-04-01        7.25
# 1 2020-05-01        7.60
# 2 2020-06-01        7.25
# 3 2020-07-01       11.50
# 4 2020-08-01       17.00

# %% [markdown]
# # **Google Search Trends for "enflasyon"**

# %%
file_path = '/content/drive/My Drive/dsa210/monthly_enflasyon.csv'

enflasyon_df = pd.read_csv(file_path, skiprows=1)
enflasyon_df.columns = ["Month", "enflasyon_trend"]
enflasyon_df["Month"] = pd.to_datetime(enflasyon_df["Month"])

#print first 5 element
print(enflasyon_df.head())

#Bar chart
plt.figure(figsize=(16, 6))
plt.bar(enflasyon_df["Month"].dt.strftime('%Y-%m'), enflasyon_df["enflasyon_trend"], color='green')
plt.title("Monthly Average Trend: Enflasyon")
plt.xlabel("Month")
plt.ylabel("Trend Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

#Line chart
plt.figure(figsize=(16, 6))
plt.plot(enflasyon_df["Month"], enflasyon_df["enflasyon_trend"], marker='o', color='green')
plt.title("Monthly Average Trend: Enflasyon")
plt.xlabel("Month")
plt.ylabel("Trend Value")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#        Month  enflasyon_trend
# 0 2020-04-01             4.25
# 1 2020-05-01             8.80
# 2 2020-06-01            12.25
# 3 2020-07-01             4.25
# 4 2020-08-01             6.60

# %% [markdown]
# # **TCMB- Monthly Inflation Rates**

# %%
file_path = '/content/drive/My Drive/dsa210/inflationTCMB.csv'
inflation_tcmb_df = pd.read_csv(file_path, skiprows=1)
inflation_tcmb_df.columns = ["index", "Year", "Month_Name", "Annual_Change", "Date"]
inflation_tcmb_df["Date"] = pd.to_datetime(inflation_tcmb_df["Date"])

#print first 5 element
print(inflation_tcmb_df.head())

#Bar chart
plt.figure(figsize=(16, 6))
plt.bar(inflation_tcmb_df["Date"].dt.strftime('%Y-%m'), inflation_tcmb_df["Annual_Change"], color='tomato')
plt.title("Monthly Inflation Rate – Bar Chart")
plt.xlabel("Date")
plt.ylabel("Annual Change (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Line chart
plt.figure(figsize=(16, 6))
plt.plot(inflation_tcmb_df["Date"], inflation_tcmb_df["Annual_Change"], marker='o', linestyle='-', color='tomato')
plt.title("Monthly Inflation Rate – Line Chart")
plt.xlabel("Date")
plt.ylabel("Annual Change (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#    index  Year Month_Name  Annual_Change       Date
# 0     18  2020      April          10.94 2020-04-01
# 1     24  2020        May          11.39 2020-05-01
# 2     30  2020       June          12.62 2020-06-01
# 3     36  2020       July          11.76 2020-07-01
# 4     42  2020     August          11.77 2020-08-01

# %% [markdown]
# # **TCMB- Monthly Interest Rates**

# %%
file_path = '/content/drive/My Drive/dsa210/faizTCMB.csv'
faiz_tcmb_df = pd.read_csv(file_path, skiprows=1)
faiz_tcmb_df.columns = ["index", "Year", "Month_Name", "Interest", "Date"]
faiz_tcmb_df["Date"] = pd.to_datetime(faiz_tcmb_df["Date"])

print(faiz_tcmb_df.head())

# bar chart
plt.figure(figsize=(16, 6))
plt.bar(faiz_tcmb_df["Date"].dt.strftime('%Y-%m'), faiz_tcmb_df["Interest"], color='deepskyblue')
plt.title("Monthly TCMB Interest Rate – Bar Chart")
plt.xlabel("Date")
plt.ylabel("Interest Rate (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# line chart
plt.figure(figsize=(16, 6))
plt.plot(faiz_tcmb_df["Date"], faiz_tcmb_df["Interest"], marker='o', linestyle='-', color='deepskyblue')
plt.title("Monthly TCMB Interest Rate – Line Chart")
plt.xlabel("Date")
plt.ylabel("Interest Rate (%)")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#    index  Year Month_Name  Interest       Date
# 0    286  2020      April      0.69 2020-04-01
# 1    287  2020        May      0.59 2020-05-01
# 2    288  2020       June      0.59 2020-06-01
# 3    289  2020       July      0.57 2020-07-01
# 4    290  2020     August      0.71 2020-08-01

# %% [markdown]
# ## **HYPOTHESIS TESTS**
#
# **Interest Rate Changes and Search Trends:** Increases or decreases in TCMB’s interest rates correlate with fluctuations in search volumes for "faiz" (interest rate) and "dollar/euro."
#
# **Inflation and Public Interest:**
# Rising inflation leads to increased searches for "enflasyon" (inflation), as the public seeks more information about its impact on daily life.

# %% [markdown]
# **Interest Rate Changes and Search Trends**
#
# Null Hpothesis: There is no correlation between TCMB's interest rates and "faiz" search volume.
#
# Alternative Hypotesis: There is a positive correlation between interest rates and "faiz" search volume.
#
# If p-value is smaller than 0.05, reject Null Hypothesis.
# ********************
# Null Hpothesis: There is no correlation between TCMB's interest rates and "dolar" search volume.
#
# Alternative Hypotesis: There is a positive correlation between interest rates and "dolar" search volume.
#
# If p-value is smaller than 0.05, reject Null Hypothesis.
# ******************
# Null Hpothesis: There is no correlation between TCMB's interest rates and "euro" search volume.
#
# Alternative Hypotesis: There is a positive correlation between interest rates and "euro" search volume.
#
# If p-value is smaller than 0.05, reject Null Hypothesis.

# %%
# Merge and clean
merged = pd.merge(faiz_tcmb_df[["Month", "Interest"]], faiz_df, on="Month").dropna(subset=["Interest", "faiz_trend"])

# Spearman correlation
corr, pval = spearmanr(merged["Interest"], merged["faiz_trend"])

#results
print("Spearman Correlation:", round(corr, 3))
print("P-value:", round(pval, 5))
if pval < 0.05:
    print("Result: Reject H₀. Significant positive correlation.")
else:
    print("Result: Fail to reject H₀. No significant correlation.")


import matplotlib.pyplot as plt

#sp
plt.figure()
plt.scatter(merged["Interest"], merged["faiz_trend"])
plt.title("Scatter: TCMB Interest Rate vs. Google Trends ('faiz')")
plt.xlabel("TCMB Interest Rate (%)")
plt.ylabel("Google Trends 'faiz' Value")
plt.tight_layout()
plt.show()
# Out:
# Spearman Correlation: 0.606
# P-value: 0.0
# Result: Reject H₀. Significant positive correlation.

# %%
#data clean
faiz_tcmb_df["Month"] = pd.to_datetime(faiz_tcmb_df["Date"]).dt.to_period("M")
merged = pd.merge(faiz_tcmb_df[["Month", "Interest"]], dolar_df, on="Month")
merged = merged.dropna(subset=["Interest", "dolar_trend"])

#spearman corr.
corr, pval = spearmanr(merged["Interest"], merged["dolar_trend"])

print("Spearman Correlation Coefficient:", round(corr, 3))
print("P-value:", round(pval, 5))

#results
if pval < 0.05:
    print("Result: Reject the null hypothesis. Significant positive correlation.")
else:
    print("Result: Fail to reject the null hypothesis.")


#sp
plt.figure()
plt.scatter(merged["Interest"], merged["dolar_trend"])
plt.title("Scatter: TCMB Interest Rate vs. Google Trends ('dolar')")
plt.xlabel("TCMB Interest Rate (%)")
plt.ylabel("Google Trends 'dolar' Value")
plt.tight_layout()
plt.show()
# Out:
# Spearman Correlation Coefficient: -0.453
# P-value: 0.00031
# Result: Reject the null hypothesis. Significant positive correlation.

# %%
#data clean
if euro_df["Month"].dtype != "period[M]":
    euro_df["Month"] = pd.to_datetime(euro_df["Month"]).dt.to_period("M")
merged = pd.merge(faiz_tcmb_df[["Month", "Interest"]], euro_df, on="Month").dropna(subset=["Interest", "euro_trend"])
faiz_tcmb_df["Month"] = pd.to_datetime(faiz_tcmb_df["Date"]).dt.to_period("M")
merged = pd.merge(faiz_tcmb_df[["Month", "Interest"]], euro_df, on="Month")
merged = merged.dropna(subset=["Interest", "euro_trend"])

corr, pval = spearmanr(merged["Interest"], merged["euro_trend"])

print("Spearman Correlation Coefficient:", round(corr, 3))
print("P-value:", round(pval, 5))

#results
if pval < 0.05:
    print("Result: Reject the null hypothesis. Significant positive correlation.")
else:
    print("Result: Fail to reject the null hypothesis. No significant correlation found.")

#sp
plt.figure()
plt.scatter(merged["Interest"], merged["euro_trend"])
plt.title("Scatter: TCMB Interest Rate vs. Google Trends ('euro')")
plt.xlabel("TCMB Interest Rate (%)")
plt.ylabel("Google Trends 'euro' Value")
plt.tight_layout()
plt.show()
# Out:
# Spearman Correlation Coefficient: 0.187
# P-value: 0.15547
# Result: Fail to reject the null hypothesis. No significant correlation found.

# %% [markdown]
# ***Conclusion***
#
# There is a statistically significant positive correlation between TCMB's interest rates and "faiz" search volume.
#
# There is a statistically significant positive correlation between TCMB's interest rates and "dolar" search volume.
#
#  There is no statistically significant correlation between TCMB's interest rates and "euro" search volume.

# %% [markdown]
# **Inflation and Public Interest**
#
# Null Hpothesis: There is no correlation between TCMB's inflation rates and "inflation" search volume.
#
# Alternative Hypotesis: There is a positive correlation between inflation rates and "inflation" search volume.
#
# If p-value is smaller than 0.05, reject Null Hypothesis.

# %%
from scipy.stats import spearmanr
import pandas as pd
import matplotlib.pyplot as plt



inflation_tcmb_df["Month"] = pd.to_datetime(inflation_tcmb_df["Date"]).dt.to_period("M")
monthly_inflation = inflation_tcmb_df[["Month", "Annual_Change"]]


merged = pd.merge(monthly_inflation, enflasyon_df, on="Month").dropna()

#Spearman
corr, pval = spearmanr(merged["Annual_Change"], merged["enflasyon_trend"])


print("Spearman Correlation:", round(corr, 3))
print("P-value:", round(pval, 5))

if pval < 0.05:
    print("Result: Reject the Null Hypothesis.")
else:
    print("Result: Fail to Reject the Null Hypothesis.")

#Scatter plot
plt.figure(figsize=(10, 6))
plt.scatter(merged["Annual_Change"], merged["enflasyon_trend"], color='darkorange')
plt.title("Scatter Plot: TCMB Inflation Rate vs 'Enflasyon' Search Trend")
plt.xlabel("TCMB Inflation Rate (Annual % Change)")
plt.ylabel("Google Search Trend: 'Enflasyon'")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Spearman Correlation: 0.66
# P-value: 0.0
# Result: Reject the Null Hypothesis.

# %% [markdown]
# ***Conclusion***
#
# There is a positive correlation between inflation rates and "inflation" search volume.
